# %% [markdown]
# # 보스턴 집값 예측
#
#
# ### 0. 데이터 준비

# %%
# from sklearn.datasets import load_boston

# %%
import pandas as pd
import numpy as np

data_url = "http://lib.stat.cmu.edu/datasets/boston"
raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
target = raw_df.values[1::2, 2]

# %% [markdown]
# ### 1. 데이터 확인

# %%
# Variables in order:
# CRIM     per capita crime rate by town
# ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
# INDUS    proportion of non-retail business acres per town
# CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
# NOX      nitric oxides concentration (parts per 10 million)
# RM       average number of rooms per dwelling
# AGE      proportion of owner-occupied units built prior to 1940
# DIS      weighted distances to five Boston employment centres
# RAD      index of accessibility to radial highways
# TAX      full-value property-tax rate per $10,000
# PTRATIO  pupil-teacher ratio by town
# B        1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
# LSTAT    % lower status of the population
# MEDV     Median value of owner-occupied homes in $1000's

# %%
# 내가 집값을 예측하는데 사용하는 특성(특징) -> data = input value
data.shape
# Out:
# (506, 13)

# %%
# 내가 예측하고자 하는 대상 -> target = output valur or target value
target.shape
# Out:
# (506,)

# %%
data[1]
# Out:
# array([2.7310e-02, 0.0000e+00, 7.0700e+00, 0.0000e+00, 4.6900e-01,
#        6.4210e+00, 7.8900e+01, 4.9671e+00, 2.0000e+00, 2.4200e+02,
#        1.7800e+01, 3.9690e+02, 9.1400e+00])

# %%
target[1]
# Out:
# 21.6

# %% [markdown]
# ### 2. 모델링
#
# - 선형회귀
#
# ※ 참고
# - 회귀 : 연속적인 값을 예측 (집 값, 키, 몸무게) 170 170.1 170.2
# - 분류 : 정해진 개수로 분류 (숫자, 감정분석) 0 ~ 9, 긍정/부정

# %%
from sklearn.linear_model import LinearRegression

# %%
LinearRegression?

# %%
model = LinearRegression()

# %%
model
# Out:
# LinearRegression()

# %% [markdown]
# ### 3. 테스트 데이터 준비
#
# - 학습데이터랑 테스트데이터를 분리하는 이유
#
# 1. 학습 때 (모델이 데이터를 확인함) 보지 못한 데이터를 얼마나 잘 예측하는지 검증하기 위해서
#
# 2. 여러모델을 비교하기 위해서

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(data, target)

# %%
X_train.shape
# Out:
# (379, 13)

# %%
X_test.shape
# Out:
# (127, 13)

# %%
y_train.shape, y_test.shape
# Out:
# ((379,), (127,))

# %% [markdown]
# ### 4. 모델 학습

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# 가중치
model.coef_
# Out:
# array([-7.80306299e-02,  4.72470104e-02,  2.12631650e-02,  2.18404824e+00,
#        -1.82957982e+01,  3.00111034e+00,  1.77330840e-02, -1.60119427e+00,
#         2.68215625e-01, -1.22563037e-02, -9.80184408e-01,  8.56860910e-03,
#        -6.23816992e-01])

# %%
# 편차
model.intercept_
# Out:
# 43.2042087752995

# %%
# 집값 = -7.80...*2.01... + ... + 43.2042...
y = a x1+bx2+cx3+... + bias

# %% [markdown]
# ### 5. 모델 평가

# %%
model.score(X_test, y_test)
# Out:
# 0.7028586625554369
